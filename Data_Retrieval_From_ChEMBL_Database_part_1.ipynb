# %% [markdown]
# <a href="https://colab.research.google.com/github/nebirsad/antiHIV/blob/main/Data_Retrieval_From_ChEMBL_Database_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Retrieval From ChEMBL Database**
# My name is **Dr. Ashfaq Ahmad**, and this tutorial is inspired from the TechOpenCADD project of Volkamer Lab. With some minor modifications, I tried to made it available for the students working with a Biology background. For Proper understanding and learning, you can follow the video tutorial on **Bioinformatics Insights** https://www.youtube.com/channel/UC2Z_WaqTjbvXGGQNpIF9nAg
#
# This notebook is majorly designed for teaching purposes.
#
# For citation and reading, https://jcheminf.biomedcentral.com/articles/10.1186/s13321-019-0351-x

# %% [markdown]
# **Learning and Training Objectives**
# 1. Retrieving compound data and activities from ChEMBL for a protein (receptor) of your choice.
# **Understanding units**
#
# **1. IC50** is a standared unit used in biochemical assays for inhibition. It stands for Inhibitory concentration at 50 or Half maximal inhibitory concentration. The lower value indicates higher potency of a drug. You may also see **pIC50**, that is = -log10(IC50). It makes the opposite of IC50, meaning higher pIC50 means higher potency of a drug.
#
# Let's begin,

# %% [markdown]
# ##Pre-requisite Installation and Imports

# %%
! pip install chembl_webresource_client
! pip install rdkit
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.8.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.2.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.4.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.1 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.0 MB/s eta 0:00:00
# Downloading cattrs-25.2.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 5.1 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.2.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1
# Collecting rdkit
#   Downloading rdkit-2025.3.6-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2025.3.6-cp312-cp312-manylinux_2_28_x86_64.whl (36.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 30.0 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.3.6

# %%
import math
from pathlib import Path
from zipfile import ZipFile
from tempfile import TemporaryDirectory

import numpy as np
import pandas as pd
from rdkit.Chem import PandasTools
from chembl_webresource_client.new_client import new_client
from tqdm.auto import tqdm

# %%
HERE = Path(_dh[-1])
DATA = HERE / "data"

# %% [markdown]
# Creating some API tokens for target

# %%
targets_api = new_client.target
compounds_api = new_client.molecule
bioactivities_api = new_client.activity

# %%
type(targets_api)
# Out:
# chembl_webresource_client.query_set.QuerySet

# %% [markdown]
# In this tutorial we will use **Epidermal Growth Factor (EGFR)** protein, which is a kinase by nature. We will fetch them from Uniprot Accession ID.

# %%
uniprot_id = "P61073"

# %%
# Get target information from ChEMBL but restrict it to specified values only
targets = targets_api.get(target_components__accession=uniprot_id).only(
    "target_chembl_id", "organism", "pref_name", "target_type"
)
print(f'The type of the targets is "{type(targets)}"')
# Out:
# The type of the targets is "<class 'chembl_webresource_client.query_set.QuerySet'>"

# %%
targets = pd.DataFrame.from_records(targets)
targets
# Out:
#        organism                        pref_name target_chembl_id  \
# 0  Homo sapiens  C-X-C chemokine receptor type 4       CHEMBL2107
# 1  Homo sapiens  C-X-C chemokine receptor type 4       CHEMBL2107
#
#       target_type
# 0  SINGLE PROTEIN
# 1  SINGLE PROTEIN

# %% [markdown]
# Below we will select the exact ChEMBL data via index options

# %%
target = targets.iloc[0]
target
# Out:
# organism                               Homo sapiens
# pref_name           C-X-C chemokine receptor type 4
# target_chembl_id                         CHEMBL2107
# target_type                          SINGLE PROTEIN
# Name: 0, dtype: object

# %%
chembl_id = target.target_chembl_id
print(f"The target ChEMBL ID is {chembl_id}")
# NBVAL_CHECK_OUTPUT
# Out:
# The target ChEMBL ID is CHEMBL2107

# %% [markdown]
# Below we are going to fetch some important variable of the data for ourself. You can change them if you want to extract some other column.

# %%
bioactivities = bioactivities_api.filter(
    target_chembl_id=chembl_id, type="IC50", relation="=", assay_type="B"
).only(
    "activity_id",
    "assay_chembl_id",
    "assay_description",
    "assay_type",
    "molecule_chembl_id",
    "type",
    "standard_units",
    "relation",
    "standard_value",
    "target_chembl_id",
    "target_organism",
)

print(f"Length and type of bioactivities object: {len(bioactivities)}, {type(bioactivities)}")
# Out:
# Length and type of bioactivities object: 618, <class 'chembl_webresource_client.query_set.QuerySet'>

# %% [markdown]
# Each entry in our bioactivity set holds the following information:

# %%
print(f"Length and type of first element: {len(bioactivities[0])}, {type(bioactivities[0])}")
bioactivities[0]
# Out:
# Length and type of first element: 13, <class 'dict'>
# {'activity_id': 309250,
#  'assay_chembl_id': 'CHEMBL884098',
#  'assay_description': 'Inhibitory activity against CX3C chemokine receptor 4-specific monoclonal antibody 12G5 (mAb-12G5) binding to human chemokinin receptor CXCR4 in lymphocytic SUP-T1 cells',
#  'assay_type': 'B',
#  'molecule_chembl_id': 'CHEMBL1202230',
#  'relation': '=',
#  'standard_units': 'nM',
#  'standard_value': '4363.0',
#  'target_chembl_id': 'CHEMBL2107',
#  'target_organism': 'Homo sapiens',
#  'type': 'IC50',
#  'units': 'uM',
#  'value': '4.363'}

# %% [markdown]
# Download the dataset

# %%
#Downloading Data
bioactivities_df = pd.DataFrame.from_dict(bioactivities)
print(f"DataFrame shape: {bioactivities_df.shape}")
bioactivities_df.head()
# Out:
# DataFrame shape: (618, 13)
#    activity_id assay_chembl_id  \
# 0       309250    CHEMBL884098
# 1       314505    CHEMBL884098
# 2       326718    CHEMBL884098
# 3       336034    CHEMBL884098
# 4       338599    CHEMBL884098
#
#                                    assay_description assay_type  \
# 0  Inhibitory activity against CX3C chemokine rec...          B
# 1  Inhibitory activity against CX3C chemokine rec...          B
# 2  Inhibitory activity against CX3C chemokine rec...          B
# 3  Inhibitory activity against CX3C chemokine rec...          B
# 4  Inhibitory activity against CX3C chemokine rec...          B
#
#   molecule_chembl_id relation standard_units standard_value target_chembl_id  \
# 0      CHEMBL1202230        =             nM         4363.0       CHEMBL2107
# 1      CHEMBL2311089        =             nM            7.0       CHEMBL2107
# 2       CHEMBL543895        =             nM           67.0       CHEMBL2107
# 3       CHEMBL538038        =             nM         5737.0       CHEMBL2107
# 4      CHEMBL1202231        =             nM            1.0       CHEMBL2107
#
#   target_organism  type units  value
# 0    Homo sapiens  IC50    uM  4.363
# 1    Homo sapiens  IC50    uM  0.007
# 2    Homo sapiens  IC50    uM  0.067
# 3    Homo sapiens  IC50    uM  5.737
# 4    Homo sapiens  IC50    uM  0.001

# %% [markdown]
# It is possible that some of the rows show redundant data, but do not worry we will remove that later
#
# **Now we want to know how many different units are present in the data**

# %%
bioactivities_df["units"].unique()
# Out:
# array(['uM', 'nM', 'ug ml-1'], dtype=object)

# %% [markdown]
# Below we will do some tweaking with units to make them uniform

# %%
bioactivities_df.drop(["units", "value"], axis=1, inplace=True)
bioactivities_df.head()
# Out:
#    activity_id assay_chembl_id  \
# 0       309250    CHEMBL884098
# 1       314505    CHEMBL884098
# 2       326718    CHEMBL884098
# 3       336034    CHEMBL884098
# 4       338599    CHEMBL884098
#
#                                    assay_description assay_type  \
# 0  Inhibitory activity against CX3C chemokine rec...          B
# 1  Inhibitory activity against CX3C chemokine rec...          B
# 2  Inhibitory activity against CX3C chemokine rec...          B
# 3  Inhibitory activity against CX3C chemokine rec...          B
# 4  Inhibitory activity against CX3C chemokine rec...          B
#
#   molecule_chembl_id relation standard_units standard_value target_chembl_id  \
# 0      CHEMBL1202230        =             nM         4363.0       CHEMBL2107
# 1      CHEMBL2311089        =             nM            7.0       CHEMBL2107
# 2       CHEMBL543895        =             nM           67.0       CHEMBL2107
# 3       CHEMBL538038        =             nM         5737.0       CHEMBL2107
# 4      CHEMBL1202231        =             nM            1.0       CHEMBL2107
#
#   target_organism  type
# 0    Homo sapiens  IC50
# 1    Homo sapiens  IC50
# 2    Homo sapiens  IC50
# 3    Homo sapiens  IC50
# 4    Homo sapiens  IC50

# %% [markdown]
# **Data Processing and Filteration**
#
# Delete entries with missing and duplicate values.
#
# Reset index number and rename columns.

# %%
bioactivities_df.dtypes
# Out:
# activity_id            int64
# assay_chembl_id       object
# assay_description     object
# assay_type            object
# molecule_chembl_id    object
# relation              object
# standard_units        object
# standard_value        object
# target_chembl_id      object
# target_organism       object
# type                  object
# dtype: object

# %%
bioactivities_df = bioactivities_df.astype({"standard_value": "float64"})
bioactivities_df.dtypes
# Out:
# activity_id             int64
# assay_chembl_id        object
# assay_description      object
# assay_type             object
# molecule_chembl_id     object
# relation               object
# standard_units         object
# standard_value        float64
# target_chembl_id       object
# target_organism        object
# type                   object
# dtype: object

# %%
bioactivities_df.dropna(axis=0, how="any", inplace=True)
print(f"DataFrame shape: {bioactivities_df.shape}")
# Out:
# DataFrame shape: (618, 11)

# %%
print(f"Units in downloaded data: {bioactivities_df['standard_units'].unique()}")
print(
    f"Number of non-nM entries:\
    {bioactivities_df[bioactivities_df['standard_units'] != 'nM'].shape[0]}"
)
# Out:
# Units in downloaded data: ['nM' 'ug.mL-1']
# Number of non-nM entries:    35

# %%
bioactivities_df = bioactivities_df[bioactivities_df["standard_units"] == "nM"]
print(f"Units after filtering: {bioactivities_df['standard_units'].unique()}")
# Out:
# Units after filtering: ['nM']

# %%
print(f"DataFrame shape: {bioactivities_df.shape}")
# Out:
# DataFrame shape: (583, 11)

# %%
bioactivities_df.drop_duplicates("molecule_chembl_id", keep="first", inplace=True)
print(f"DataFrame shape: {bioactivities_df.shape}")
# Out:
# DataFrame shape: (478, 11)

# %%
bioactivities_df.reset_index(drop=True, inplace=True)
bioactivities_df.head()
# Out:
#    activity_id assay_chembl_id  \
# 0       309250    CHEMBL884098
# 1       314505    CHEMBL884098
# 2       326718    CHEMBL884098
# 3       336034    CHEMBL884098
# 4       338599    CHEMBL884098
#
#                                    assay_description assay_type  \
# 0  Inhibitory activity against CX3C chemokine rec...          B
# 1  Inhibitory activity against CX3C chemokine rec...          B
# 2  Inhibitory activity against CX3C chemokine rec...          B
# 3  Inhibitory activity against CX3C chemokine rec...          B
# 4  Inhibitory activity against CX3C chemokine rec...          B
#
#   molecule_chembl_id relation standard_units  standard_value target_chembl_id  \
# 0      CHEMBL1202230        =             nM          4363.0       CHEMBL2107
# 1      CHEMBL2311089        =             nM             7.0       CHEMBL2107
# 2       CHEMBL543895        =             nM            67.0       CHEMBL2107
# 3       CHEMBL538038        =             nM          5737.0       CHEMBL2107
# 4      CHEMBL1202231        =             nM             1.0       CHEMBL2107
#
#   target_organism  type
# 0    Homo sapiens  IC50
# 1    Homo sapiens  IC50
# 2    Homo sapiens  IC50
# 3    Homo sapiens  IC50
# 4    Homo sapiens  IC50

# %%
bioactivities_df.rename(
    columns={"standard_value": "IC50", "standard_units": "units"}, inplace=True
)
bioactivities_df.head()
# Out:
#    activity_id assay_chembl_id  \
# 0       309250    CHEMBL884098
# 1       314505    CHEMBL884098
# 2       326718    CHEMBL884098
# 3       336034    CHEMBL884098
# 4       338599    CHEMBL884098
#
#                                    assay_description assay_type  \
# 0  Inhibitory activity against CX3C chemokine rec...          B
# 1  Inhibitory activity against CX3C chemokine rec...          B
# 2  Inhibitory activity against CX3C chemokine rec...          B
# 3  Inhibitory activity against CX3C chemokine rec...          B
# 4  Inhibitory activity against CX3C chemokine rec...          B
#
#   molecule_chembl_id relation units    IC50 target_chembl_id target_organism  \
# 0      CHEMBL1202230        =    nM  4363.0       CHEMBL2107    Homo sapiens
# 1      CHEMBL2311089        =    nM     7.0       CHEMBL2107    Homo sapiens
# 2       CHEMBL543895        =    nM    67.0       CHEMBL2107    Homo sapiens
# 3       CHEMBL538038        =    nM  5737.0       CHEMBL2107    Homo sapiens
# 4      CHEMBL1202231        =    nM     1.0       CHEMBL2107    Homo sapiens
#
#    type
# 0  IC50
# 1  IC50
# 2  IC50
# 3  IC50
# 4  IC50

# %%
print(f"DataFrame shape: {bioactivities_df.shape}")
# Out:
# DataFrame shape: (478, 11)

# %% [markdown]
# **Fetch compound data from ChEMBL**
#
# Let’s have a look at the compounds from ChEMBL which we have defined so far. bioactivity data for: We are going to fetch compound ChEMBL IDs and structures for the compounds linked to our filtered bioactivity data.

# %%
compounds_provider = compounds_api.filter(
    molecule_chembl_id__in=list(bioactivities_df["molecule_chembl_id"])
).only("molecule_chembl_id", "molecule_structures")

# %% [markdown]
# **Download Compounds**

# %%
compounds = list(tqdm(compounds_provider))
# Out:
#   0%|          | 0/478 [00:00<?, ?it/s]

# %%
compounds_df = pd.DataFrame.from_records(
    compounds,
)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (478, 2)

# %%
compounds_df.head()
# Out:
#   molecule_chembl_id                                molecule_structures
# 0        CHEMBL18442  {'canonical_smiles': 'c1cc(CN2CCCNCCNCCCNCC2)c...
# 1       CHEMBL409991  {'canonical_smiles': 'C[C@H]1/C=C\[C@@H](CCCCN...
# 2       CHEMBL440638  {'canonical_smiles': 'C[C@H]1/C=C\[C@@H](CCCCN...
# 3       CHEMBL266632  {'canonical_smiles': 'C[C@H]1/C=C\[C@@H](CCCCN...
# 4       CHEMBL440998  {'canonical_smiles': 'C[C@H]1/C=C\[C@@H](CCCCN...

# %%
compounds_df.dropna(axis=0, how="any", inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (478, 2)

# %%
compounds_df.drop_duplicates("molecule_chembl_id", keep="first", inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (478, 2)

# %%
compounds_df.iloc[0].molecule_structures.keys()
# Out:
# dict_keys(['canonical_smiles', 'molfile', 'standard_inchi', 'standard_inchi_key'])

# %%
canonical_smiles = []

for i, compounds in compounds_df.iterrows():
    try:
        canonical_smiles.append(compounds["molecule_structures"]["canonical_smiles"])
    except KeyError:
        canonical_smiles.append(None)

compounds_df["smiles"] = canonical_smiles
compounds_df.drop("molecule_structures", axis=1, inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (478, 2)

# %%
compounds_df.dropna(axis=0, how="any", inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (478, 2)

# %% [markdown]
# **Let's output compound bioactivity data**

# %%
print(f"Bioactivities filtered: {bioactivities_df.shape[0]}")
bioactivities_df.columns
# Out:
# Bioactivities filtered: 478
# Index(['activity_id', 'assay_chembl_id', 'assay_description', 'assay_type',
#        'molecule_chembl_id', 'relation', 'units', 'IC50', 'target_chembl_id',
#        'target_organism', 'type'],
#       dtype='object')

# %%
print(f"Compounds filtered: {compounds_df.shape[0]}")
compounds_df.columns
# Out:
# Compounds filtered: 478
# Index(['molecule_chembl_id', 'smiles'], dtype='object')

# %% [markdown]
# **Lets merge both the datasets**
#
# Merge to contain, molecule ID, IC50, Units, and canonical smiles

# %%
# Merge DataFrames
output_df = pd.merge(
    bioactivities_df[["molecule_chembl_id", "IC50", "units"]],
    compounds_df,
    on="molecule_chembl_id",
)

# Reset row indices
output_df.reset_index(drop=True, inplace=True)

print(f"Dataset with {output_df.shape[0]} entries.")
# Out:
# Dataset with 478 entries.

# %%
output_df.dtypes
# Out:
# molecule_chembl_id     object
# IC50                  float64
# units                  object
# smiles                 object
# dtype: object

# %%
output_df.head(10)
# Out:
#   molecule_chembl_id      IC50 units  \
# 0      CHEMBL1202230    4363.0    nM
# 1      CHEMBL2311089       7.0    nM
# 2       CHEMBL543895      67.0    nM
# 3       CHEMBL538038    5737.0    nM
# 4      CHEMBL1202231       1.0    nM
# 5       CHEMBL409991    6900.0    nM
# 6       CHEMBL439700  170000.0    nM
# 7       CHEMBL266632   36000.0    nM
# 8       CHEMBL440638    5000.0    nM
# 9       CHEMBL440998    5000.0    nM
#
#                                               smiles
# 0  Br.c1cc2nc(c1)CNCCN(Cc1ccc(CN3CCNCc4cccc(n4)CN...
# 1  Cl.Cl.Cl.Cl.Cl.Cl.Cl.Cl.O.O.c1cc(CN2CCCNCCNCCC...
# 2    Br.c1cc(CN2CCCNCCNCCNCCC2)ccc1CN1CCCNCCNCCNCCC1
# 3  Br.CC(=O)O.Clc1cc2nc(c1)CNCCCN(Cc1ccc(CN3CCCNC...
# 4  Br.c1cc2nc(c1)CCNCCN(Cc1ccc(CN3CCNCCc4cccc(n4)...
# 5  C[C@H]1/C=C\[C@@H](CCCCN)NC(=O)[C@H](CCCCN)NC(...
# 6  C[C@H]1/C=C\[C@@H](CCCCN)NC(=O)[C@H](CCCCN)NC(...
# 7  C[C@H]1/C=C\[C@@H](CCCCN)NC(=O)[C@H](CCCCN)NC(...
# 8  C[C@H]1/C=C\[C@@H](CCCCN)NC(=O)[C@H](CCCCN)NC(...
# 9  C[C@H]1/C=C\[C@@H](CCCCN)NC(=O)[C@H](CCCCN)NC(...

# %% [markdown]
# **Convert IC50 values into pIC50 and put it in an extra column**

# %%
def convert_ic50_to_pic50(IC50_value):
    pIC50_value = 9 - math.log10(IC50_value)
    return pIC50_value

# %%
# Apply conversion to each row of the compounds DataFrame
output_df["pIC50"] = output_df.apply(lambda x: convert_ic50_to_pic50(x.IC50), axis=1)

# %%
output_df.head()
# Out:
#   molecule_chembl_id    IC50 units  \
# 0      CHEMBL1202230  4363.0    nM
# 1      CHEMBL2311089     7.0    nM
# 2       CHEMBL543895    67.0    nM
# 3       CHEMBL538038  5737.0    nM
# 4      CHEMBL1202231     1.0    nM
#
#                                               smiles     pIC50
# 0  Br.c1cc2nc(c1)CNCCN(Cc1ccc(CN3CCNCc4cccc(n4)CN...  5.360215
# 1  Cl.Cl.Cl.Cl.Cl.Cl.Cl.Cl.O.O.c1cc(CN2CCCNCCNCCC...  8.154902
# 2    Br.c1cc(CN2CCCNCCNCCNCCC2)ccc1CN1CCCNCCNCCNCCC1  7.173925
# 3  Br.CC(=O)O.Clc1cc2nc(c1)CNCCCN(Cc1ccc(CN3CCCNC...  5.241315
# 4  Br.c1cc2nc(c1)CCNCCN(Cc1ccc(CN3CCNCCc4cccc(n4)...  9.000000

# %% [markdown]
# **Distribution Based on IpIC50**

# %%
output_df.hist(column="pIC50")
# Out:
# array([[<Axes: title={'center': 'pIC50'}>]], dtype=object)

# %% [markdown]
# In the next steps, we add a column for RDKit molecule objects to our DataFrame and look at the structures of the molecules with the highest pIC50 values.

# %%
# Add molecule column
PandasTools.AddMoleculeColumnToFrame(output_df, smilesCol="smiles")

# %%
# Sort molecules by pIC50
output_df.sort_values(by="pIC50", ascending=False, inplace=True)

# Reset index
output_df.reset_index(drop=True, inplace=True)

# %%
output_df.drop("smiles", axis=1).head(3)
# Out:
#   molecule_chembl_id  IC50 units     pIC50  \
# 0       CHEMBL237830  0.30    nM  9.522879
# 1      CHEMBL1242210  0.34    nM  9.468521
# 2       CHEMBL393882  0.60    nM  9.221849
#
#                                               ROMol
# 0  <rdkit.Chem.rdchem.Mol object at 0x787fd6a345f0>
# 1  <rdkit.Chem.rdchem.Mol object at 0x787fd6a3ee30>
# 2  <rdkit.Chem.rdchem.Mol object at 0x787fd6a3dd90>

# %%
# Prepare saving the dataset: Drop the ROMol column
output_df = output_df.drop("ROMol", axis=1)
print(f"DataFrame shape: {output_df.shape}")
# Out:
# DataFrame shape: (478, 5)

# %% [markdown]
# **Save Dataset for Next Session**

# %%
output_df.to_csv("/content/cxcr4_dataset1.csv")
output_df.head()
# Out:
#   molecule_chembl_id  IC50 units  \
# 0       CHEMBL237830  0.30    nM
# 1      CHEMBL1242210  0.34    nM
# 2       CHEMBL393882  0.60    nM
# 3      CHEMBL2062277  0.61    nM
# 4      CHEMBL1242211  0.61    nM
#
#                                               smiles     pIC50
# 0                   c1ccc(NCc2ccc(CNc3ccccn3)cc2)nc1  9.522879
# 1  CN1CCN(c2cccc3nc(CN(C)[C@H]4CCCc5cccnc54)c(CO)...  9.468521
# 2  N=C(N)NCCC[C@H](NC(=O)[C@@H]1CSSC[C@H](NC(=O)[...  9.221849
# 3  CCCN(CCC)CCCCN(C)Cc1ccc(CN(Cc2ncc[nH]2)Cc2nccn...  9.214670
# 4  CCCN(CCC)CCCCN(C)Cc1ccc(CN(Cc2ncc[nH]2)Cc2nccn...  9.214670

# %%
print(f"DataFrame shape: {output_df.shape}")
# NBVAL_CHECK_OUTPUT
# Out:
# DataFrame shape: (478, 5)

# %% [markdown]
# ##**Congratulation! You have started learning something new**
#
# If you happy for your time, Please provide your Support in the Form of a Subscription on Youtube Channel**
#
# [**Bioinformatics Insights**](https://www.youtube.com/channel/UC2Z_WaqTjbvXGGQNpIF9nAg)
#
# Follow [**WhatsApp Channel**](https://whatsapp.com/channel/0029VajkwkdCHDydS6Y2lM36) for further updates, research services, and courses.
